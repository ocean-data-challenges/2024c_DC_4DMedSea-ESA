# %% [markdown]
# ![header1](../figures/dc_2024_4dmedsea_banner.jpg)

# %% [markdown]
# # Benchmark exp_20162017 4DVarNet V2 geostrophic currents maps
#
#
# ***
# **Authors:**  CLS & Datlas <br>
# **Copyright:** 2023 CLS & Datlas <br>
# **License:** MIT
#
# <div class="alert alert-block alert-success">
# <h1><center>Benchmark exp_20162017 of 4DVarNet V2 geostrophic currents maps</center></h1>
# </div>

# %%
from glob import glob
import numpy as np
import os
import sys
import warnings
warnings.filterwarnings("ignore")

# %%
sys.path.append('..')
from src.mod_plot import *
from src.mod_stat import *
from src.mod_spectral import *
from src.mod_interp import *
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(> .cell-output-ipywidget-background
#     > .lm-Widget
#     > *[data-root-id]),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>

# %%
import logging
logger = logging.getLogger()
logger.setLevel(logging.INFO)

# %% [markdown]
# <div class="alert alert-info" role="alert">
#
# <h2>0. Parameters</h2>
#
# </div>

# %%
time_min = '2016-01-08'                                        # time min for analysis
time_max = '2017-06-23'                                        # time max for analysis
output_dir = '../results'                                      # output directory path
os.system(f'mkdir -p {output_dir}')

box_lonlat = {'lon_min':-6,
              'lon_max':36,
              'lat_min':30,
              'lat_max':46 }

method_name = '4DVarNet_V2'

stat_output_filename = f'{output_dir}/stat_exp_20162017_uv_'+method_name+'.nc'  # output statistical analysis filename
rmse_filename = f'{output_dir}/rmse_exp_20162017_uv_'+method_name+'.nc'
lambda_min = 65.                                               # minimun spatial scale in kilometer to consider on the filtered signal
lambda_max = 500.                                              # maximum spatial scale in kilometer to consider on the filtered signal
psd_output_filename = f'{output_dir}/psd_exp_20162017_uv_'+method_name+'.nc'    # output spectral analysis filename 
 
segment_lenght =  np.timedelta64(40, 'D')                      # spectral parameter: drifters segment lenght in days to consider in the spectral analysis

# %% [markdown]
# <div class="alert alert-info" role="alert">
#
# <h2>1. Input files</h2>
#
# </div>

# %% [markdown]
# ## [Sea Surface currents from Drifters database](https://doi.org/10.17882/86236)

# %%
filenames_drifters = sorted(glob('../data/exp_20162017/eval/indep_drifters/uv_drifters_*.nc'))

# %%
ds_drifter = xr.open_mfdataset(filenames_drifters, combine='nested', concat_dim='time')
ds_drifter = ds_drifter.where((ds_drifter.time >= np.datetime64(time_min)) & (ds_drifter.time <=  np.datetime64(time_max)), drop=True)
ds_drifter
# Out:
# <xarray.Dataset>
# Dimensions:    (time: 12936)
# Coordinates:
#   * time       (time) datetime64[ns] 2017-01-01 ... 2017-12-31
#     latitude   (time) float32 dask.array<chunksize=(28,), meta=np.ndarray>
#     longitude  (time) float32 dask.array<chunksize=(28,), meta=np.ndarray>
# Data variables:
#     EWCT       (time) float32 dask.array<chunksize=(28,), meta=np.ndarray>
#     NSCT       (time) float32 dask.array<chunksize=(28,), meta=np.ndarray>
#     sensor_id  (time) float64 dask.array<chunksize=(28,), meta=np.ndarray>
# Attributes: (12/46)
#     data_type:                   OceanSITES trajectory data
#     format_version:              2.0
#     platform_code:               10162380
#     date_update:                 2020-10-13T12:09:42Z
#     institution:                 AOML
#     institution_edmo_code:       1799
#     ...                          ...
#     deployment_lat:              58.64
#     last_longitude_observation:  53.59
#     last_latitude_observation:   70.81
#     date_drog_lost:              2013-07-28T17:00:00Z
#     death_type:                  buoy ran aground
#     last_date_observation:       2017-03-16T12:01:00Z

# %% [markdown]
# ## Sea Surface current maps to evaluate

# %%
list_of_maps = sorted(glob('../data/maps/4DVarNet/*.nc'))
ds_maps = xr.open_mfdataset(list_of_maps, combine='nested', concat_dim='time')
ds_maps = ds_maps.sel(time=slice(time_min, time_max))
ds_maps
# Out:
# <xarray.Dataset>
# Dimensions:             (time: 365, latitude: 378, longitude: 1012)
# Coordinates:
#   * time                (time) datetime64[ns] 2017-01-01 ... 2017-12-31
#   * longitude           (longitude) float32 -6.062 -6.021 -5.979 ... 36.02 36.06
#   * latitude            (latitude) float32 30.27 30.31 30.35 ... 45.94 45.98
# Data variables:
#     sla                 (time, latitude, longitude) float64 dask.array<chunksize=(1, 378, 1012), meta=np.ndarray>
#     ugosa               (time, latitude, longitude) float64 dask.array<chunksize=(1, 378, 1012), meta=np.ndarray>
#     vgosa               (time, latitude, longitude) float64 dask.array<chunksize=(1, 378, 1012), meta=np.ndarray>
#     relative_vorticity  (time, latitude, longitude) float64 dask.array<chunksize=(1, 378, 1012), meta=np.ndarray>
#     adt                 (time, latitude, longitude) float64 dask.array<chunksize=(1, 378, 1012), meta=np.ndarray>
#     ugos                (time, latitude, longitude) float64 dask.array<chunksize=(1, 378, 1012), meta=np.ndarray>
#     vgos                (time, latitude, longitude) float64 dask.array<chunksize=(1, 378, 1012), meta=np.ndarray>

# %% [markdown]
# <div class="alert alert-info" role="alert">
#
# <h2>2. Statistical & Spectral Analysis </h2>
#
# </div>

# %% [markdown]
# ## 2.1 Interpolate sea surface currents maps onto drifters positions

# %%
ds_interp = run_interpolation_drifters(ds_maps, ds_drifter, time_min, time_max)
ds_interp = ds_interp.dropna('time')
ds_interp = ds_interp.sortby('time')
ds_interp
# Out:
# 2024-01-12 10:31:00 INFO     fetch data from 2017-01-01 00:00:00 to 2017-02-01 00:00:00
# 2024-01-12 10:31:01 INFO     fetch data from 2017-01-01 00:00:00 to 2017-02-01 00:00:00
# 2024-01-12 10:31:01 INFO     fetch data from 2017-01-31 00:00:00 to 2017-03-01 00:00:00
# 2024-01-12 10:31:02 INFO     fetch data from 2017-01-31 00:00:00 to 2017-03-01 00:00:00
# 2024-01-12 10:31:02 INFO     fetch data from 2017-02-28 00:00:00 to 2017-04-01 00:00:00
# 2024-01-12 10:31:03 INFO     fetch data from 2017-02-28 00:00:00 to 2017-04-01 00:00:00
# 2024-01-12 10:31:03 INFO     fetch data from 2017-03-31 00:00:00 to 2017-05-01 00:00:00
# 2024-01-12 10:31:04 INFO     fetch data from 2017-03-31 00:00:00 to 2017-05-01 00:00:00
# 2024-01-12 10:31:05 INFO     fetch data from 2017-04-30 00:00:00 to 2017-06-01 00:00:00
# 2024-01-12 10:31:05 INFO     fetch data from 2017-04-30 00:00:00 to 2017-06-01 00:00:00
# 2024-01-12 10:31:06 INFO     fetch data from 2017-05-31 00:00:00 to 2017-07-01 00:00:00
# 2024-01-12 10:31:07 INFO     fetch data from 2017-05-31 00:00:00 to 2017-07-01 00:00:00
# 2024-01-12 10:31:07 INFO     fetch data from 2017-06-30 00:00:00 to 2017-08-01 00:00:00
# 2024-01-12 10:31:08 INFO     fetch data from 2017-06-30 00:00:00 to 2017-08-01 00:00:00
# 2024-01-12 10:31:09 INFO     fetch data from 2017-07-31 00:00:00 to 2017-09-01 00:00:00
# 2024-01-12 10:31:10 INFO     fetch data from 2017-07-31 00:00:00 to 2017-09-01 00:00:00
# 2024-01-12 10:31:10 INFO     fetch data from 2017-08-31 00:00:00 to 2017-10-01 00:00:00
# 2024-01-12 10:31:11 INFO     fetch data from 2017-08-31 00:00:00 to 2017-10-01 00:00:00
# 2024-01-12 10:31:12 INFO     fetch data from 2017-09-30 00:00:00 to 2017-11-01 00:00:00
# 2024-01-12 10:31:12 INFO     fetch data from 2017-09-30 00:00:00 to 2017-11-01 00:00:00
# 2024-01-12 10:31:13 INFO     fetch data from 2017-10-31 00:00:00 to 2017-12-01 00:00:00
# 2024-01-12 10:31:13 INFO     fetch data from 2017-10-31 00:00:00 to 2017-12-01 00:00:00
# 2024-01-12 10:31:14 INFO     fetch data from 2017-11-30 00:00:00 to 2017-12-31 00:00:00
# 2024-01-12 10:31:15 INFO     fetch data from 2017-11-30 00:00:00 to 2017-12-31 00:00:00
# <xarray.Dataset>
# Dimensions:            (time: 12428)
# Coordinates:
#   * time               (time) datetime64[ns] 2017-01-01 ... 2017-12-31
# Data variables:
#     EWCT               (time) float32 -0.08076 -0.01872 ... -0.07887 -0.1121
#     NSCT               (time) float32 -0.0398 -0.1397 ... 0.1432 -0.08049
#     sensor_id          (time) float64 1.349e+05 6.205e+07 ... 6.357e+07
#     latitude           (time) float32 40.19 32.16 31.83 ... 37.39 31.49 36.52
#     longitude          (time) float32 7.622 16.0 16.56 ... 4.46 33.13 34.62
#     ugos_interpolated  (time) float64 -0.03515 -0.062 ... 0.1247 -0.08247
#     vgos_interpolated  (time) float64 0.0747 -0.06376 ... -0.0001414 0.03464

# %% [markdown]
# ## 2.2 Compute grid boxes statistics & statistics by regime (coastal, offshore low variability, offshore high variability)

# %%
# Compute gridded stats
compute_stat_scores_uv(ds_interp, stat_output_filename, method_name=method_name)
# Out:
# 2024-01-12 10:31:15 INFO     Compute mapping error all scales
# 2024-01-12 10:31:15 INFO     Compute statistics
# Total RMSE u= 0.1321259820633347 m/s
# Total RMSE v= 0.1352365357189829 m/s
# Total RMSE u score= 0.29534584794135366
# Total RMSE v score= 0.25005296537723554
# 2024-01-12 10:31:17 INFO     Stat file saved as: ../results/stat_uv_4DVarNet.nc
# 2024-01-12 10:31:17 INFO     Compute statistics by oceanic regime

# %%
# Plot gridded stats
# Hvplot
# plot_stat_score_map_uv(stat_output_filename)
# Matplotlib
plot_stat_score_map_uv_png(stat_output_filename, box_lonlat=box_lonlat)

# %% [markdown]
# The figure shows that the maximum mapping errors are found in intense current systems, for example in the GulfStream, Kuroshio and Agulhas regions.
#
# However, when considering the full scale of motion in the drifter database, the surface current maps capture up to 80% of the variability of drifter currents in the Western Boundary Currents and Antarctic Circumpolar Currents (ACC). The geostrophic signal dominates the ageostrophic signal in these regions. In regions with low ocean variability, only a few percent of the total drifter current variability is recovered in the maps, which may be associated with a larger ageostrophic signal in these regions.

# %%
plot_stat_uv_by_regimes(stat_output_filename)
# Out:
#                   mapping_err_u_var [m²/s²]  mapping_err_v_var [m²/s²]  \
# coastal                            0.017465                   0.018303
# offshore_highvar                        NaN                        NaN
# offshore_lowvar                    0.014057                   0.015083
# equatorial_band                         NaN                        NaN
# arctic                                  NaN                        NaN
# antarctic                               NaN                        NaN
#
#                   ugos_interpolated_var [m²/s²]  EWCT_var [m²/s²]  \
# coastal                                0.019537          0.034546
# offshore_highvar                            NaN               NaN
# offshore_lowvar                        0.025955          0.028101
# equatorial_band                             NaN               NaN
# arctic                                      NaN               NaN
# antarctic                                   NaN               NaN
#
#                   vgos_interpolated_var [m²/s²]  NSCT_var [m²/s²]  \
# coastal                                0.014068          0.032282
# offshore_highvar                            NaN               NaN
# offshore_lowvar                        0.037519          0.050307
# equatorial_band                             NaN               NaN
# arctic                                      NaN               NaN
# antarctic                                   NaN               NaN
#
#                   var_score_u_allscale  var_score_v_allscale
# coastal                       0.494444              0.433017
# offshore_highvar                   NaN                   NaN
# offshore_lowvar               0.499759              0.700186
# equatorial_band                    NaN                   NaN
# arctic                             NaN                   NaN
# antarctic                          NaN                   NaN

# %%
compute_temporal_rmse(ds_interp, method_name, time_min, time_max, rmse_filename, var_type='uv')

# %%
plot_temporal_rmse(rmse_filename, var_type='uv')
